# %%
# Copyright (c) Microsoft Corporation.
# Licensed under the MIT License.
import sys
from batteryml.pipeline import Pipeline
from batteryml.visualization.plot_helper import plot_capacity_degradation, plot_cycle_attribute, plot_result

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Basic Usage Of BatteryML Pipeline

# %% [markdown]
# ## Create pipeline

# %%
# Create a pipeline with a configuration file, specifying the device and workspace. 
# Developers need to modify the data, feature, model and other related settings in the config file in advance. 
pipeline = Pipeline(config_path='configs/baselines/sklearn/variance_model/matr_1.yaml',
                    workspace='workspaces')
# Out:
# workspaces

# %% [markdown]
# ## Train and evaluate

# %%
model, dataset = pipeline.train(device='cuda', skip_if_executed=False)
# Out:
# Seed is set to 0.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model, dataset = pipeline.train(device='cuda', skip_if_executed=False)
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\pipeline.py:51, in Pipeline.train(self, seed, epochs, device, ckpt_to_resume, skip_if_executed, dataset)
#      49 # Prepare dataset
#      50 if dataset is None:
# ---> 51     dataset, raw_data = build_dataset(self.config, device)
#      52     self.raw_data = raw_data
#      53 # Number of epochs override
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\pipeline.py:202, in build_dataset(configs, device, config_fields)
#     200         raw_data = data['raw_data']
#     201 else:
# --> 202     task = Task(
#     203         label_annotator=configs['label'],
#     204         feature_extractor=configs['feature'],
#     205         train_test_splitter=configs['train_test_split'],
#     206         feature_transformation=configs['feature_transformation'],
#     207         label_transformation=configs['label_transformation'])
#     209     dataset = task.build()
#     210     train_cells, test_cells = task.get_raw_data()
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\task.py:27, in Task.__init__(self, train_test_splitter, feature_extractor, label_annotator, feature_transformation, label_transformation)
#      19 def __init__(self,
#      20              train_test_splitter: dict,
#      21              feature_extractor: dict,
#      22              label_annotator: dict,
#      23              feature_transformation: BaseDataTransformation = None,
#      24              label_transformation: BaseDataTransformation = None):
#      25     if isinstance(train_test_splitter, dict):
#      26         train_test_splitter = \
# ---> 27             TRAIN_TEST_SPLITTERS.build(train_test_splitter, 'raise')
#      28     if isinstance(feature_extractor, dict):
#      29         feature_extractor = FEATURE_EXTRACTORS.build(feature_extractor)
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\utils\registry.py:54, in Registry.build(self, config, error_handle, **kwargs)
#      51     return
#      53 if name in self.class_mapping:
# ---> 54     return self.class_mapping[name](**{
#      55         k: v for k, v in config.items()
#      56         if k != 'name' and k not in kwargs
#      57     }, **kwargs)
#      58 else:
#      59     if error_handle.lower() != 'ignore':
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\train_test_split\MATR_split.py:61, in MATRPrimaryTestTrainTestSplitter.__init__(self, cell_data_path)
#      53 # NOTE: the Nature Energy and ECS papers do not deal with the
#      54 #       outlier point b2c1. Actually, directly fitting an NN
#      55 #       leads to large error on this cell. However, contrastive
#      56 #       learning will not suffer from this issue. For fair
#      57 #       comparison, here we delete it from the test split.
#      58 #       You can always try to add it back to see the effect.
#      59 test_ids.pop(test_ids.index('b2c1'))
# ---> 61 MATRTrainTestSplitter.__init__(
#      62     self, cell_data_path, train_ids, test_ids)
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\train_test_split\MATR_split.py:11, in MATRTrainTestSplitter.__init__(self, cell_data_path, train_ids, test_ids)
#      10 def __init__(self, cell_data_path: str, train_ids: list, test_ids: list):
# ---> 11     BaseTrainTestSplitter.__init__(self, cell_data_path)
#      12     # NOTE: the filename should be the cell IDs
#      13
#      14     # Build a map from train_id to file_path
#      15     path_map = {}
#
# File c:\Users\FanWang\Documents\GitHub\BatteryML\batteryml\train_test_split\base.py:25, in BaseTrainTestSplitter.__init__(self, cell_data_path)
#      23 for path in cell_data_path:
#      24     path = Path(path)
# ---> 25     assert path.exists(), path
#      27     if path.is_dir():
#      28         self._file_list += list(path.glob('*.pkl'))
#
# AssertionError: data\processed\MATR

# %%
train_prediction = model.predict(dataset, data_type='train')
train_loss = dataset.evaluate(train_prediction, 'RMSE', data_type='train') 
test_prediction = model.predict(dataset, data_type='test')
test_loss = dataset.evaluate(test_prediction, 'RMSE', data_type='test')
print(f'RMSE: Train {train_loss:.2f}, test {test_loss:.2f}')

# %%
pipeline.evaluate(model=model, dataset=dataset, skip_if_executed=False)

# %% [markdown]
# ## Plot train and test data

# %%
# get raw data from pipeline
train_cells, test_cells  = pipeline.raw_data['train_cells'], pipeline.raw_data['test_cells']

# %%
# display (train set) all battery cells' capacity degradation curve using plot_capacity_degradation function

plot_capacity_degradation(train_cells, title='plot degradation of train set discharge capacity', figsize=(8,6), n_legend_cols=2)

# %%
# display (test set) all battery cells' capacity degradation curve using plot_capacity_degradation function

plot_capacity_degradation(test_cells, title='plot degradation of test1 set discharge capacity', figsize=(8,6), n_legend_cols=2, ylim=(0.75,1.1))

# %%
# plot cycle raw attribute such as "voltage_in_V","current_in_A","charge_capacity_in_Ah","discharge_capacity_in_Ah"...

cell_0 = train_cells[10]
indices = [i for i in range(0, 100, 2) if i!=10 ]
plot_cycle_attribute(cell_0.cycle_data, 'voltage_in_V', cycle_indices=indices, figsize=(10, 4))

# %%
# plot cycle attribute such as "coulombic_efficiency"...
indices = [i for i in range(500) if i!=10 ]
plot_cycle_attribute(cell_0.cycle_data, 'coulombic_efficiency', cycle_indices=indices)

# %% [markdown]
# ## Plot result

# %%
prediction = model.predict(dataset, data_type='test').to('cpu')
ground_truth = dataset.test_data.label.to('cpu')
plot_result(ground_truth, prediction)

# %% [markdown]
# # Baseline

# %%
import os
import pandas as pd
config_dir = 'configs/baselines/'
data1 = 'matr_1'
data2 = 'matr_2'
result=[]
for method_type in os.listdir(config_dir):
    for method in os.listdir(os.path.join(config_dir, method_type)):
        print(method)
        config_path = os.path.join(config_dir, method_type, method, f'{data1}.yaml')
        pipeline = Pipeline(config_path=config_path,
                    
                    workspace=f'workspaces/{method}')
        # train_loss , test_loss = pipeline.train()
        model, dataset = pipeline.train(device='cuda', skip_if_executed=False)
        train_prediction = model.predict(dataset, data_type='train')
        train_loss = dataset.evaluate(train_prediction, 'RMSE', data_type='train') 
        test_prediction = model.predict(dataset, data_type='test')
        test_loss = dataset.evaluate(test_prediction, 'RMSE', data_type='test')
        
        config_path = os.path.join(config_dir, method_type, method, f'{data2}.yaml')
        pipeline = Pipeline(config_path=config_path,
                    workspace=f'workspaces/{method}')
        model, dataset = pipeline.train(device='cuda', skip_if_executed=False)
        test_prediction = model.predict(dataset, data_type='test')
        test2_loss = dataset.evaluate(test_prediction, 'RMSE', data_type='test')
        result.append([method, train_loss, test_loss, test2_loss])

res = pd.DataFrame(data=result, columns=['method', 'train_RMSE', 'test_RMSE', 'test2_RMSE'])

# %%
res
